# %%
from keras import layers
import tensorflow as tf
import pandas as pd
import numpy as np

# Make numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)


df = pd.read_csv('../csv_dateien/starcraftFinalcsvs/allRunsButOnlyTerran.csv')

conditions = [
    (df['fraction'] == "Protoss"), #1
    (df['fraction'] == "Terraner"), #2
    (df['fraction'] == "Zerg"), #3
    (df['fraction'] == "T"), #2
]

values = [1, 2, 3, 2]

df["fraction"] = np.select(conditions, values)
df=df[df["total_army"]>0]
df=df[df["fraction"]==2]
df=df[df["supply"]<=200]
df["ratio"] = df["total_workers"]/df["total_army"]

dfPrepSample = df.drop(columns=["player","winner","replay_filename", "Unnamed: 0", "total_workers", "total_army_value","fraction"])
len(dfPrepSample)
# Out:
# 3009

# %%
# optimizer with scaling and lin reg

import warnings
import gurobipy as gp
import matplotlib.pyplot as plt
from sklearn import tree
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score
from sklearn.compose import make_column_transformer
import gurobipy_pandas as gppd
from gurobi_ml import add_predictor_constr



# ,player,total_workers,total_army_value,total_army,fraction,winner,replay_filename
dfOpt = dfPrepSample.drop(columns=[
                               "ratio"])

dfOpt.head
# Out:
# <bound method NDFrame.head of       resource_mining  total_army  supply  time
# 1               28154        96.0   174.0   836
# 6               40998       120.0   196.0   934
# 15              13965        45.0   117.0   583
# 19               9595        26.0    62.0   449
# 24              38030        98.0   165.0  1102
# ...               ...         ...     ...   ...
# 5888             7364        17.0    69.0   381
# 5889            25845        80.0   173.0   878
# 5893            26351        70.0   157.0   795
# 5894            24263        76.0   165.0   754
# 5895            22655        40.0   125.0   726
#
# [3009 rows x 4 columns]>

# %%
# create variables
# create Model

m = gp.Model("Balance optimizer")
gppd.set_interactive()

r = gppd.add_vars(m, pandas_obj=dfOpt,
                  name="ratio")

a = gppd.add_vars(m, pandas_obj=dfOpt,
                  name="total_army")
s = gppd.add_vars(m, pandas_obj=dfOpt,
                  name="supply")
w = m.addVar(name="workers", vtype=gp.GRB.INTEGER)

m.update()
dfOpt = dfOpt.drop(columns=["total_army"])

feats = dfOpt
feats = pd.concat([r, feats], axis=1)
feats.head
# Out:
# <bound method NDFrame.head of                          ratio  resource_mining  supply  time
# 1        <gurobi.Var ratio[1]>            28154   174.0   836
# 6        <gurobi.Var ratio[6]>            40998   196.0   934
# 15      <gurobi.Var ratio[15]>            13965   117.0   583
# 19      <gurobi.Var ratio[19]>             9595    62.0   449
# 24      <gurobi.Var ratio[24]>            38030   165.0  1102
# ...                        ...              ...     ...   ...
# 5888  <gurobi.Var ratio[5888]>             7364    69.0   381
# 5889  <gurobi.Var ratio[5889]>            25845   173.0   878
# 5893  <gurobi.Var ratio[5893]>            26351   157.0   795
# 5894  <gurobi.Var ratio[5894]>            24263   165.0   754
# 5895  <gurobi.Var ratio[5895]>            22655   125.0   726
#
# [3009 rows x 4 columns]>

# %%
sc_model = tf.keras.models.load_model('sc_ts_model.h5')

# %%
m.setObjective(a.sum(), gp.GRB.MAXIMIZE) # Zielfunktion
"""
gppd.add_constrs(m, ((av - 50*w)/100), gp.GRB.GREATER_EQUAL, a) # Gleichung 2
"""
gppd.add_constrs(m, r * a, gp.GRB.EQUAL, w)
gppd.add_constrs(m, w + a, gp.GRB.GREATER_EQUAL, 0) # Gleichung 3
gppd.add_constrs(m, w + a, gp.GRB.LESS_EQUAL, s) # Gleichung 4
m.addConstr(w, gp.GRB.GREATER_EQUAL, 1)
m.update()

pred_constr = add_predictor_constr(m, sc_model, feats, a) # Einfügen des Regressiosmodells
pred_constr.print_stats()
m.Params.NonConvex = 2
m.optimize()
# Out:
# Model for sequential1:
# 45135 variables
# 21063 constraints
# 18054 general constraints
# Input has shape (3009, 4)
# Output has shape (3009, 1)
#
# --------------------------------------------------------------------------------
# Layer           Output Shape    Variables              Constraints
#                                                 Linear    Quadratic      General
# ================================================================================
# dense0             (3009, 3)        18054         9027            0         9027 (relu)
#
# dense1             (3009, 3)        18054         9027            0         9027 (relu)
#
# dense2             (3009, 1)            0         3009            0            0
#
# --------------------------------------------------------------------------------
# Set parameter NonConvex to value 2
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11800H @ 2.30GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 27082 rows, 54163 columns and 108325 nonzeros
# Model fingerprint: 0x5c6bb40b
# Model has 3009 quadratic constraints
# Model has 18054 general constraints
# Variable types: 54162 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [9e-04, 2e+01]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [2e+01, 9e+04]
#   RHS range        [1e+00, 6e+00]
# Presolve removed 12285 rows and 30464 columns
# Presolve time: 0.92s
# Presolved: 26833 rows, 23700 columns, 65400 nonzeros
# Presolved model has 5894 SOS constraint(s)
# Presolved model has 3009 bilinear constraint(s)
# Variable types: 17807 continuous, 5893 integer (5892 binary)
#
# Root relaxation: unbounded, 18969 iterations, 0.19 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  postponed    0               -          -      -     -    1s
#      0     0  postponed    0               -          -      -     -    1s
# Exploring 100 nodes in MinRel heuristic
# MinRel: 73 nodes explored, relaxation 1.00e+100, total elapsed time 5s
# No solution found by MinRel heuristic
#      0     2  postponed    0               -          -      -     -    6s
#    114    30  postponed   10               -          -      -  1418   10s
#    320    31  postponed   21               -          -      -   541   15s
#    457    41 infeasible   27               -          -      -   400   21s
#    596    45 infeasible   35               -          -      -   354   25s
#    770    42 infeasible   42               -          -      -   291   30s
#    864    46 infeasible   46               -          -      -   266   37s
#    960    51 infeasible   50               -          -      -   323   40s
#   1062    59 infeasible   54               -          -      -   402   48s
#   1126    60 infeasible   56               -          -      -   442   50s
#   1266    82  postponed   10               -          -      -   428   56s
#   1449   113  postponed   21               -          -      -   489   61s
#   1568   125  postponed   27               -          -      -   518   66s
#   1708   142  postponed   31               -          -      -   542   70s
#   1867   157  postponed   38               -          -      -   562   75s
#   2032   172  postponed   48               -          -      -   581   80s
#   2221   173 infeasible   55               -          -      -   564   86s
#   2442   183  postponed   62               -          -      -   528   92s
#   2662   192 infeasible   74               -          -      -   497   99s
#   2885   202 infeasible   78               -          -      -   480  107s
#   3173   215 infeasible   87               -          -      -   448  115s
#   3468   233 infeasible   94               -          -      -   415  123s
#   3756   238 infeasible  100               -          -      -   393  132s
#   4067   246  postponed  110               -          -      -   374  142s
#   4393   253 infeasible  118               -          -      -   365  151s
#   4726   267  postponed   40               -          -      -   386  163s
#   5160   272 infeasible   60               -          -      -   368  177s
#   5623   285 infeasible   79               -          -      -   351  191s
#   6106   300 infeasible   95               -          -      -   352  205s
#   6611   308  postponed  110               -          -      -   349  219s
#   7091   331  postponed  128               -          -      -   354  234s
#   7582   360  postponed  145               -          -      -   378  251s
# Exploring 10000 nodes in MinRel heuristic
# MinRel: 30 nodes explored, relaxation 1.19e+06, total elapsed time 255s
# MinRel: 578 nodes explored, relaxation 1.19e+06, total elapsed time 260s
# MinRel: 1415 nodes explored, relaxation 1.19e+06, total elapsed time 265s
# MinRel: 2222 nodes explored, relaxation 1.19e+06, total elapsed time 270s
# MinRel: 2641 nodes explored, relaxation 1.19e+06, total elapsed time 275s
# MinRel: 2902 nodes explored, relaxation 1.19e+06, total elapsed time 280s
# MinRel: 3172 nodes explored, relaxation 1.19e+06, total elapsed time 285s
# MinRel: 3341 nodes explored, relaxation 1.19e+06, total elapsed time 290s
# MinRel: 3712 nodes explored, relaxation 1.19e+06, total elapsed time 295s
# MinRel: 3921 nodes explored, relaxation 1.19e+06, total elapsed time 300s
# MinRel: 4036 nodes explored, relaxation 1.19e+06, total elapsed time 305s
# MinRel: 4267 nodes explored, relaxation 1.19e+06, total elapsed time 310s
# MinRel: 4518 nodes explored, relaxation 1.19e+06, total elapsed time 315s
# MinRel: 4783 nodes explored, relaxation 1.19e+06, total elapsed time 320s
# MinRel: 5041 nodes explored, relaxation 1.19e+06, total elapsed time 325s
# MinRel: 5342 nodes explored, relaxation 1.19e+06, total elapsed time 330s
# MinRel: 5666 nodes explored, relaxation 1.19e+06, total elapsed time 335s
# MinRel: 5666 nodes explored, relaxation 1.19e+06, total elapsed time 340s
# MinRel: 6453 nodes explored, relaxation 1.19e+06, total elapsed time 345s
# MinRel: 7339 nodes explored, relaxation 1.19e+06, total elapsed time 350s
# MinRel: 7816 nodes explored, relaxation 1.19e+06, total elapsed time 355s
# MinRel: 8505 nodes explored, relaxation 1.19e+06, total elapsed time 360s
# MinRel: 9134 nodes explored, relaxation 1.19e+06, total elapsed time 365s
# MinRel: 9928 nodes explored, relaxation 1.19e+06, total elapsed time 370s
# No solution found by MinRel heuristic
#   8149   367  postponed   11               -          -      -   401  374s
#   8151   369  postponed   12               -          -      -   403  375s
#   8238   367 infeasible   21               -          -      -   425  380s
#   8303   360 1.2586e+18   23 5953          -          -      -   422  385s
#   8362   406 1.2586e+18   26 5950          -          -      -   423  390s
#   8476   506 1.2586e+18   35 5941          -          -      -   421  395s
#   8967   849 1.2586e+18   69 5907          -          -      -   398  400s
#   9543  1330 1.2586e+18  109 5867          -          -      -   374  405s
#  10115  1807 1.2586e+18  149 5827          -          -      -   353  413s
#  10273  2072 1.2586e+18  160 5816          -          -      -   348  416s
#  10702  2509 1.2586e+18  190 5786          -          -      -   334  420s
#  11405  3239 1.2576e+18  232 5745          -          -      -   314  426s
#  12047  3890 1.2586e+18  280 5697          -          -      -   298  431s
#  12497  4188 1.2586e+18  316 5661          -          -      -   287  436s
#  12845  4725 1.2577e+18  339 5638          -          -      -   280  450s
#  13419  5354 1.2578e+18  383 5594          -          -      -   268  455s
#  13850  5803 1.2586e+18  417 5560          -          -      -   260  460s
#  14214  6172 1.2586e+18  444 5533          -          -      -   253  473s
#  14585  6609 1.2586e+18  472 5505          -          -      -   247  477s
#  15026  6961 1.2586e+18  505 5472          -          -      -   240  480s
#  15614  7684 1.2586e+18  551 5426          -          -      -   231  487s
#  16130  8211 1.2586e+18  588 5389          -          -      -   224  492s
#  90511 28895 2.8926e+17 4300 3009          -          -      -  52.2 1217s
#  91144 28894 infeasible 4344               -          -      -  51.9 1229s
#  91693 28893 infeasible 4382               -          -      -  51.7 1240s
#  92358 28894 2.4463e+17 4430 3009          -          -      -  51.5 1251s
#  93021 28892 infeasible 4476               -          -      -  51.2 1267s
#  93495 28892 2.1929e+17 4510 3009          -          -      -  51.1 1278s
#  94217 28892 2.0420e+17 4560 3009          -          -      -  51.0 1289s
#  94929 28896 1.8964e+17 4610 3009          -          -      -  50.7 1300s
#  95653 28892 infeasible 4660               -          -      -  50.6 1317s
#  96373 28894 1.6176e+17 4712 3009          -          -      -  50.3 1333s
#  96843 28894 infeasible 4742               -          -      -  50.2 1344s
#  97609 28895 infeasible 4796               -          -      -  49.9 1356s
#  98388 28892 infeasible 4850               -          -      -  49.8 1368s
#  99165 28893 1.1476e+17 4906 3009          -          -      -  49.5 1379s
#  99954 28892 1.0262e+17 4962 3009          -          -      -  49.4 1392s
#  100679 28893 infeasible 5012               -          -      -  49.2 1404s
#  101474 28894 infeasible 5068               -          -      -  49.0 1420s
#  101995 28894 infeasible 5104               -          -      -  49.0 1432s
#  102817 28894 infeasible 5162               -          -      -  48.8 1443s
#  103635 28894 infeasible 5220               -          -      -  48.7 1454s
#  104457 28893 infeasible 5278               -          -      -  48.5 1465s
#  105286 28894 infeasible 5336               -          -      -  48.4 1477s
#  106115 28896 infeasible 5394               -          -      -  48.4 1494s
#  106667 28892 infeasible 5436               -          -      -  48.4 1507s
#  107507 28895 1.9135e+16 5496 3009          -          -      -  48.3 1518s
#  108340 28892 infeasible 5554               -          -      -  48.1 1528s
#  109177 28895 9.8863e+15 5614 3009          -          -      -  47.8 1541s
#  110008 28894 infeasible 5672               -          -      -  47.7 1555s
#  110707 28895 3.0749e+15 5722 3009          -          -      -  47.5 1565s
#  111556 28894 9.4029e+14 5782 3009          -          -      -  47.3 1575s
#  112399 28902 2.9787e+13 5842 3009          -          -      -  47.1 1594s
#  113595 29374 2.8070e+19   22 3032          -          -      -  46.9 1619s
#  115339 29023 infeasible   92               -          -      -  46.4 1632s
#  116066 28655 infeasible 4514               -          -      -  46.3 1647s
#  116932 28251 infeasible 4247               -          -      -  46.0 1661s
#  117782 27806 infeasible 3969               -          -      -  45.6 1674s
#  118627 27318 infeasible 3623               -          -      -  45.3 1685s
#  119473 26783 infeasible 3208               -          -      -  45.0 1695s
#  120330 26092 infeasible  924               -          -      -  44.7 1704s
#  121285 25335 infeasible 2497               -          -      -  44.3 1712s
#  122246 24503 infeasible 2083               -          -      -  44.0 1719s
#  123250 23622 infeasible 1533               -          -      -  43.6 1726s
#  124289 22740 infeasible   56               -          -      -  44.7 1733s
#  125305 21634 infeasible 4289               -          -      -  44.4 1738s
#  126539 20420 infeasible 3586               -          -      -  44.0 1743s
#  127859 19085 infeasible 2524               -          -      -  43.5 1747s
#  129284 17855 infeasible  285               -          -      -  43.5 1754s
#  130584 16241 infeasible  584               -          -      -  43.4 1759s
#  132262 15151 infeasible 1025               -          -      -  43.0 1764s
#  133413 13199 infeasible  570               -          -      -  42.6 1767s
#  135417 12451 infeasible  236               -          -      -  42.0 1771s
#  136905  9672 infeasible   41               -          -      -  41.5 1777s
#  139092  7312 infeasible 3157               -          -      -  40.9 1781s
#  144104  3547 infeasible  628               -          -      -  39.5 1787s
#  145497  3210 infeasible   29               -          -      -  39.1 1791s
#  146662  1179  postponed 2646               -          -      -  38.8 1812s
#  147732   779  postponed 2647               -          -      -  39.4 1816s
#  148138   685 infeasible 2648               -          -      -  39.7 1829s
#  148240   637  postponed 2650               -          -      -  41.0 1835s
#  148296   618 infeasible 2651               -          -      -  41.4 1854s
#  148323   557  postponed 2652               -          -      -  42.1 1857s
#  148392   522  postponed 2653               -          -      -  42.9 1863s
#  148437   506  postponed 2654               -          -      -  43.5 1871s
#  148485   510 infeasible 2656               -          -      -  43.9 1890s
#  148517   491  postponed 2657               -          -      -  45.0 1900s
#  148615   420 infeasible 2659               -          -      -  47.0 1908s
#  148709   374  postponed 2659               -          -      -  47.6 1918s
#  148761   290 infeasible 2660               -          -      -  48.0 1921s
#  148851   274  postponed 2715               -          -      -  48.5 1925s
#  148900   231  postponed 2723               -          -      -  49.2 1930s
#  149114    26  postponed 2726               -          -      -  49.8 1946s
#  149179    11 infeasible 2727               -          -      -  49.9 1953s
#  149229     7  postponed 2742               -          -      -  50.5 1955s
#  149249     2 infeasible 2746               -          -      -  51.1 1960s
#
# Cutting planes:
#   Inf proof: 24
#
# Explored 149256 nodes (7693661 simplex iterations) in 1961.42 seconds (2673.40 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 0
# No other solutions better than -1e+100
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -

# %%
outputs = pred_constr.input_values
pred_constr.input_values
# Out:
# ---------------------------------------------------------------------------
# GurobiError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 outputs = pred_constr.input_values
#       2 pred_constr.input_values
#
# File c:\Users\nicol\AppData\Local\Programs\Python\Python310\lib\site-packages\gurobi_ml\modeling\base_predictor_constr.py:211, in AbstractPredictorConstr.input_values(self)
#     197 @property
#     198 def input_values(self):
#     199     """Returns the values for the input variables if a solution is known.
#     200
#     201     Returns
#    (...)
#     208         If the Gurobi model has no solution (either was not optimized or is infeasible).
#     209     """
# --> 211     return _get_sol_values(self.input, self._input_columns, self._input_index)
#
# File c:\Users\nicol\AppData\Local\Programs\Python\Python310\lib\site-packages\gurobi_ml\modeling\_var_utils.py:66, in _get_sol_values(values, columns, index)
#      62 if isinstance(values, np.ndarray):
#      63     return np.array(
#      64         [v.X if isinstance(v, gp.Var) else v for v in values.ravel()]
#      65     ).reshape(values.shape)
# ---> 66 X = values.X
#      67 if columns is not None and HAS_PANDAS:
#      68     if isinstance(index, (pd.Index, pd.MultiIndex)):
#
# File src\gurobipy\mvar.pxi:296, in gurobipy.MVar.__getattr__()
#
# File src\gurobipy\mvar.pxi:557, in gurobipy.MVar.getAttr()
#
# File src\gurobipy\attrutil.pxi:148, in gurobipy.__gettypedattrlist()
#
# GurobiError: Unable to retrieve attribute 'X'

# %%
solution = pd.DataFrame()

solution["ratio"] = r.gppd.X
solution["supply"] = s.gppd.X
solution["army"] = a.gppd.X
solution["worker"] = w
solution

# %%
custom_palette = ["#dd8452","#4c72b0",  "#55a868"]
sns.set_theme(style="ticks")
# Show the joint distribution using kernel density estimation
g = sns.jointplot(
    data=solution, palette=custom_palette,
    x="ratio", y="supply",  # ylim=[None, 150],
    kind="kde", height=10
)
